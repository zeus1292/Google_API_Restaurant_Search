# %%
#get_businesses() is the primary function that makes the API calls to get data and format it.
#adding_list_values() is the secondary function that populates answer_list

# %%
import json
import requests
import string
import random

def get_businesses(query,api_key,min_rating=0.0,max_results=30):
    answer_list=list()
    try:
        if int(min_rating):
            None
    except:
        print("min_rating is in incorrect format")
        return answer_list
    try:
        if int(max_results):
            None
    except:
        print("max_results is in incorrect format")
        return answer_list
        
    base_url="https://maps.googleapis.com/maps/api/place/textsearch/json?"
    url=""
    query=query.replace(' ','+')
    url+=base_url+"query="+query+'&key='+api_key
    
    try:
        response=requests.get(url)
    except:
        print("Something went wrong with the API call",response.status_code)
        return
    
    try:
        data_string=response.content.decode('utf-8')
    except:
        print("There is a problem with the decoding")
        return
    
    python_data=json.loads(data_string)
    adding_list_values(answer_list,python_data,min_rating,max_results)
    if(len(answer_list)>=max_results):
        return answer_list
    while 'next_page_token' in python_data.keys():
        if(len(answer_list)>=max_results):
            break
        url=base_url+"pagetoken="+python_data['next_page_token']+"&key="+api_key
        response=requests.get(url)
        while response.json().get('status')!='OK':
            from time import sleep
            from random import random
            sleep(random())
            response=requests.get(url)
        try:
            data_string=response.content.decode('utf-8')
        except:
            print("There is a problem with the decoding")
            return
        python_data=json.loads(data_string)
        adding_list_values(answer_list,python_data,min_rating,max_results)
        
    return answer_list

def adding_list_values(answer_list,p_data,min_rating,max_results):
    for i in p_data['results']:
        flist=[]
        if len(answer_list)>=max_results:
            break
        if i['rating']<=min_rating:
            continue
        flist.append(i.get('name'))
        flist.append(i.get('formatted_address'))
        flist.append(i.get('opening_hours'))
        flist.append(i.get('price_level'))
        flist.append(i.get('rating'))
        answer_list.append(tuple(flist))
        
#API KEY    
key = ''#Enter Your API Key 

#Query string and test cases
gl_pdata=get_businesses("restaurants near Columbia University",key,4.5,45)
print(gl_pdata)
print(len(gl_pdata))
gl_pdata=get_businesses("restaurants near Columbia University",key,max_results=70)
print(gl_pdata)
print(len(gl_pdata))
gl_pdata=get_businesses("restaurants near Columbia University",key)
print(gl_pdata)
print(len(gl_pdata))
gl_pdata=get_businesses("restaurants near Columbia University",key,min_rating=None, max_results = 20)
print(gl_pdata)
print(len(gl_pdata))
gl_pdata=get_businesses("restaurants near Columbia University",key, max_results = None)
print(gl_pdata)
print(len(gl_pdata))
gl_pdata=get_businesses("restaurants near Columbia University",key,min_rating=3.0, max_results = 30)
print(gl_pdata)
print(len(gl_pdata))
gl_pdata=get_businesses("restaurants near Columbia University",key,min_rating=4.6, max_results = 50)
print(gl_pdata)
print(len(gl_pdata))
gl_pdata=get_businesses("restaurants near Columbia University",key, max_results = 20)
print(gl_pdata)
print(len(gl_pdata))
gl_pdata=get_businesses("restaurants near Columbia University",key,min_rating=4.0)
print(gl_pdata)
print(len(gl_pdata))
gl_pdata=get_businesses("restaurants near Columbia University",key,max_results='a')
print(gl_pdata)
print(len(gl_pdata))
gl_pdata=get_businesses("restaurants near Columbia University",key,min_rating='b')
print(gl_pdata)
print(len(gl_pdata))
# Out:
# [('Pisticci', '125 La Salle St, New York, NY 10027, USA', {'open_now': True}, 2, 4.6), ('Doaba Deli', '945 Columbus Ave, New York, NY 10025, USA', {'open_now': True}, 1, 4.6)]
# 2
# [("Friedman's", '1187 Amsterdam Ave, New York, NY 10027, USA', {'open_now': False}, 2, 4.2), ('Community Food & Juice', '2893 Broadway, New York, NY 10025, USA', {'open_now': False}, 2, 4.1), ('Massawa', '1239 Amsterdam Ave, New York, NY 10027, USA', {'open_now': True}, 2, 4.2), ('Pisticci', '125 La Salle St, New York, NY 10027, USA', {'open_now': True}, 2, 4.6), ('Junzi Kitchen', '2896 Broadway, New York, NY 10025, USA', {'open_now': False}, 1, 4.3), ("Brownie's Cafe", '1172 Amsterdam Ave, New York, NY 10027, USA', {'open_now': False}, None, 4.5), ('Dig Inn', '2884 Broadway, New York, NY 10025, USA', {'open_now': False}, 1, 4.3), ('Max Soha', '1274 Amsterdam Ave, New York, NY 10027, USA', {'open_now': True}, 2, 4.4), ('Symposium', '544 W 113th St, New York, NY 10025, USA', {'open_now': True}, 2, 4), ('Thai Market', '960 Amsterdam Ave, New York, NY 10025, USA', {'open_now': False}, 2, 4.3), ("Mel's Burger Bar", '2850 Broadway, New York, NY 10025, USA', {'open_now': True}, 2, 4.1), ('Roti Roll Bombay Frankie', '994 Amsterdam Ave, New York, NY 10025, USA', {'open_now': True}, 1, 4.4), ('Jin Ramen West Harlem', '3183 Broadway, New York, NY 10027, USA', {'open_now': True}, 2, 4.4), ('Kitchenette', '1272 Amsterdam Ave, New York, NY 10027, USA', {'open_now': False}, 2, 4.1), ('Flat Top', '1241 Amsterdam Ave, New York, NY 10027, USA', {'open_now': False}, 2, 4.4), ('V & T', '1024 Amsterdam Ave, New York, NY 10025, USA', {'open_now': True}, 2, 4.2), ('Doaba Deli', '945 Columbus Ave, New York, NY 10025, USA', {'open_now': True}, 1, 4.6), ('Tartina', '1034 Amsterdam Ave, New York, NY 10025, USA', {'open_now': False}, 2, 4.3), ('Saiguette', '935 Columbus Ave, New York, NY 10025, USA', {'open_now': False}, 1, 4.5), ('Chapati House - NYC', '3153 Broadway, New York, NY 10027, USA', {'open_now': True}, 1, 4.4), ('Le Monde', '2885 Broadway, New York, NY 10025, USA', {'open_now': True}, 2, 3.5), ('Max Caffè', '1262 Amsterdam Ave, New York, NY 10027, USA', {'open_now': True}, 2, 4.3), ('The Hamilton', '998 Amsterdam Ave, New York, NY 10025, USA', {'open_now': True}, 2, 4.5), ('Milano Market', '2892 Broadway, New York, NY 10025, USA', {'open_now': True}, 1, 4), ('VINATERÍA', '2211 Frederick Douglass Blvd, New York, NY 10026, USA', {'open_now': False}, 2, 4.5), ('Hamilton Deli', '1129 Amsterdam Ave, New York, NY 10025, USA', {'open_now': True}, 1, 3.7), ('John Jay Dining Hall', '519 W 114th St, New York, NY 10027, USA', {'open_now': False}, None, 3.8), ('Lido Harlem Restaurant', '2168 Frederick Douglass Blvd, New York, NY 10026, USA', {'open_now': False}, 2, 4.4), ('Shake Shack', '2957 Broadway, New York, NY 10025, USA', {'open_now': True}, 2, 4.2), ('Nikko', '1280 Amsterdam Ave, New York, NY 10027, USA', {'open_now': True}, 2, 4.2), ('Happy Hot Hunan', '969 Amsterdam Ave, New York, NY 10025, USA', {'open_now': False}, 2, 4.2), ('Strokos Gourmet Deli', '1090 Amsterdam Ave, New York, NY 10025, USA', {'open_now': False}, 1, 3.8), ('Ferris Booth Commons', 'Alfred Lerner Hall, 2920 Broadway, New York, NY 10027, USA', {'open_now': False}, None, 4), ('Kosher Cafe Nana', '606 W.115th Street, Second Floor, New York, NY 10025, United States', {'open_now': True}, None, 4.1), ('Crepes On Columbus', '990 Columbus Ave, New York, NY 10025, USA', {'open_now': False}, 2, 4.3), ('Oaxaca Taquería', '1264 Amsterdam Ave, New York, NY 10027, USA', {'open_now': True}, 1, 3.9), ('The Heights Bar & Grill', '2867 Broadway, New York, NY 10025, USA', {'open_now': True}, 2, 4.1), ('Bettolona', '3143 Broadway, New York, NY 10027, USA', {'open_now': True}, 2, 4.3), ('Famous Famiglia', '2859 Broadway, New York, NY 10025, USA', {'open_now': True}, 1, 3.9), ('Marlow Bistro', '1018 Amsterdam Ave, New York, NY 10025, USA', {'open_now': True}, 2, 4.3), ('Mezzogiorno', '2791 Broadway, New York, NY 10025, USA', {'open_now': False}, 3, 4.3), ('Maharaja Palace', '2113 Frederick Douglass Blvd, New York, NY 10026, USA', {'open_now': False}, 2, 4), ('Susan Sez "Say It With Cake"', '510 W  ...
# 60
# [("Friedman's", '1187 Amsterdam Ave, New York, NY 10027, USA', {'open_now': False}, 2, 4.2), ('Community Food & Juice', '2893 Broadway, New York, NY 10025, USA', {'open_now': False}, 2, 4.1), ('Massawa', '1239 Amsterdam Ave, New York, NY 10027, USA', {'open_now': True}, 2, 4.2), ('Pisticci', '125 La Salle St, New York, NY 10027, USA', {'open_now': True}, 2, 4.6), ('Junzi Kitchen', '2896 Broadway, New York, NY 10025, USA', {'open_now': False}, 1, 4.3), ("Brownie's Cafe", '1172 Amsterdam Ave, New York, NY 10027, USA', {'open_now': False}, None, 4.5), ('Dig Inn', '2884 Broadway, New York, NY 10025, USA', {'open_now': False}, 1, 4.3), ('Max Soha', '1274 Amsterdam Ave, New York, NY 10027, USA', {'open_now': True}, 2, 4.4), ('Symposium', '544 W 113th St, New York, NY 10025, USA', {'open_now': True}, 2, 4), ('Thai Market', '960 Amsterdam Ave, New York, NY 10025, USA', {'open_now': False}, 2, 4.3), ("Mel's Burger Bar", '2850 Broadway, New York, NY 10025, USA', {'open_now': True}, 2, 4.1), ('Roti Roll Bombay Frankie', '994 Amsterdam Ave, New York, NY 10025, USA', {'open_now': True}, 1, 4.4), ('Jin Ramen West Harlem', '3183 Broadway, New York, NY 10027, USA', {'open_now': True}, 2, 4.4), ('Kitchenette', '1272 Amsterdam Ave, New York, NY 10027, USA', {'open_now': False}, 2, 4.1), ('Flat Top', '1241 Amsterdam Ave, New York, NY 10027, USA', {'open_now': False}, 2, 4.4), ('V & T', '1024 Amsterdam Ave, New York, NY 10025, USA', {'open_now': True}, 2, 4.2), ('Doaba Deli', '945 Columbus Ave, New York, NY 10025, USA', {'open_now': True}, 1, 4.6), ('Tartina', '1034 Amsterdam Ave, New York, NY 10025, USA', {'open_now': False}, 2, 4.3), ('Saiguette', '935 Columbus Ave, New York, NY 10025, USA', {'open_now': False}, 1, 4.5), ('Chapati House - NYC', '3153 Broadway, New York, NY 10027, USA', {'open_now': True}, 1, 4.4), ('Le Monde', '2885 Broadway, New York, NY 10025, USA', {'open_now': True}, 2, 3.5), ('Max Caffè', '1262 Amsterdam Ave, New York, NY 10027, USA', {'open_now': True}, 2, 4.3), ('The Hamilton', '998 Amsterdam Ave, New York, NY 10025, USA', {'open_now': True}, 2, 4.5), ('Milano Market', '2892 Broadway, New York, NY 10025, USA', {'open_now': True}, 1, 4), ('VINATERÍA', '2211 Frederick Douglass Blvd, New York, NY 10026, USA', {'open_now': False}, 2, 4.5), ('Hamilton Deli', '1129 Amsterdam Ave, New York, NY 10025, USA', {'open_now': True}, 1, 3.7), ('John Jay Dining Hall', '519 W 114th St, New York, NY 10027, USA', {'open_now': False}, None, 3.8), ('Lido Harlem Restaurant', '2168 Frederick Douglass Blvd, New York, NY 10026, USA', {'open_now': False}, 2, 4.4), ('Shake Shack', '2957 Broadway, New York, NY 10025, USA', {'open_now': True}, 2, 4.2), ('Nikko', '1280 Amsterdam Ave, New York, NY 10027, USA', {'open_now': True}, 2, 4.2)]
# 30
# min_rating is in incorrect format
# []
# 0
# max_results is in incorrect format
# []
# 0
# [("Friedman's", '1187 Amsterdam Ave, New York, NY 10027, USA', {'open_now': False}, 2, 4.2), ('Community Food & Juice', '2893 Broadway, New York, NY 10025, USA', {'open_now': False}, 2, 4.1), ('Massawa', '1239 Amsterdam Ave, New York, NY 10027, USA', {'open_now': True}, 2, 4.2), ('Pisticci', '125 La Salle St, New York, NY 10027, USA', {'open_now': True}, 2, 4.6), ('Junzi Kitchen', '2896 Broadway, New York, NY 10025, USA', {'open_now': False}, 1, 4.3), ("Brownie's Cafe", '1172 Amsterdam Ave, New York, NY 10027, USA', {'open_now': False}, None, 4.5), ('Dig Inn', '2884 Broadway, New York, NY 10025, USA', {'open_now': False}, 1, 4.3), ('Max Soha', '1274 Amsterdam Ave, New York, NY 10027, USA', {'open_now': True}, 2, 4.4), ('Symposium', '544 W 113th St, New York, NY 10025, USA', {'open_now': True}, 2, 4), ('Thai Market', '960 Amsterdam Ave, New York, NY 10025, USA', {'open_now': False}, 2, 4.3), ("Mel's Burger Bar", '2850 Broadway, New York, NY 10025, USA', {'open_now': True}, 2, 4.1), ('Roti Roll Bombay Frankie', '994 Amsterdam Ave, New York, NY 10025, USA', {'open_now': True}, 1, 4.4), ('Jin Ramen West Harlem', '3183 Broadway, New York, NY 10027, USA', {'open_now': True}, 2, 4.4), ('Kitchenette', '1272 Amsterdam Ave, New York, NY 10027, USA', {'open_now': False}, 2, 4.1), ('Flat Top', '1241 Amsterdam Ave, New York, NY 10027, USA', {'open_now': False}, 2, 4.4), ('V & T', '1024 Amsterdam Ave, New York, NY 10025, USA', {'open_now': True}, 2, 4.2), ('Doaba Deli', '945 Columbus Ave, New York, NY 10025, USA', {'open_now': True}, 1, 4.6), ('Tartina', '1034 Amsterdam Ave, New York, NY 10025, USA', {'open_now': False}, 2, 4.3), ('Saiguette', '935 Columbus Ave, New York, NY 10025, USA', {'open_now': False}, 1, 4.5), ('Chapati House - NYC', '3153 Broadway, New York, NY 10027, USA', {'open_now': True}, 1, 4.4), ('Le Monde', '2885 Broadway, New York, NY 10025, USA', {'open_now': True}, 2, 3.5), ('Max Caffè', '1262 Amsterdam Ave, New York, NY 10027, USA', {'open_now': True}, 2, 4.3), ('The Hamilton', '998 Amsterdam Ave, New York, NY 10025, USA', {'open_now': True}, 2, 4.5), ('Milano Market', '2892 Broadway, New York, NY 10025, USA', {'open_now': True}, 1, 4), ('VINATERÍA', '2211 Frederick Douglass Blvd, New York, NY 10026, USA', {'open_now': False}, 2, 4.5), ('Hamilton Deli', '1129 Amsterdam Ave, New York, NY 10025, USA', {'open_now': True}, 1, 3.7), ('John Jay Dining Hall', '519 W 114th St, New York, NY 10027, USA', {'open_now': False}, None, 3.8), ('Lido Harlem Restaurant', '2168 Frederick Douglass Blvd, New York, NY 10026, USA', {'open_now': False}, 2, 4.4), ('Shake Shack', '2957 Broadway, New York, NY 10025, USA', {'open_now': True}, 2, 4.2), ('Nikko', '1280 Amsterdam Ave, New York, NY 10027, USA', {'open_now': True}, 2, 4.2)]
# 30
# []
# 0
# [("Friedman's", '1187 Amsterdam Ave, New York, NY 10027, USA', {'open_now': False}, 2, 4.2), ('Community Food & Juice', '2893 Broadway, New York, NY 10025, USA', {'open_now': False}, 2, 4.1), ('Massawa', '1239 Amsterdam Ave, New York, NY 10027, USA', {'open_now': True}, 2, 4.2), ('Pisticci', '125 La Salle St, New York, NY 10027, USA', {'open_now': True}, 2, 4.6), ('Junzi Kitchen', '2896 Broadway, New York, NY 10025, USA', {'open_now': False}, 1, 4.3), ("Brownie's Cafe", '1172 Amsterdam Ave, New York, NY 10027, USA', {'open_now': False}, None, 4.5), ('Dig Inn', '2884 Broadway, New York, NY 10025, USA', {'open_now': False}, 1, 4.3), ('Max Soha', '1274 Amsterdam Ave, New York, NY 10027, USA', {'open_now': True}, 2, 4.4), ('Symposium', '544 W 113th St, New York, NY 10025, USA', {'open_now': True}, 2, 4), ('Thai Market', '960 Amsterdam Ave, New York, NY 10025, USA', {'open_now': False}, 2, 4.3), ("Mel's Burger Bar", '2850 Broadway, New York, NY 10025, USA', {'open_now': True}, 2, 4.1), ('Roti Roll Bombay Frankie', '994 Amsterdam Ave, New York, NY 10025, USA', {'open_now': True}, 1, 4.4), ('Jin Ramen West Harlem', '3183 Broadway, New York, NY 10027, USA', {'open_now': True}, 2, 4.4), ('Kitchenette', '1272 Amsterdam Ave, New York, NY 10027, USA', {'open_now': False}, 2, 4.1), ('Flat Top', '1241 Amsterdam Ave, New York, NY 10027, USA', {'open_now': False}, 2, 4.4), ('V & T', '1024 Amsterdam Ave, New York, NY 10025, USA', {'open_now': True}, 2, 4.2), ('Doaba Deli', '945 Columbus Ave, New York, NY 10025, USA', {'open_now': True}, 1, 4.6), ('Tartina', '1034 Amsterdam Ave, New York, NY 10025, USA', {'open_now': False}, 2, 4.3), ('Saiguette', '935 Columbus Ave, New York, NY 10025, USA', {'open_now': False}, 1, 4.5), ('Chapati House - NYC', '3153 Broadway, New York, NY 10027, USA', {'open_now': True}, 1, 4.4)]
# 20
# [("Friedman's", '1187 Amsterdam Ave, New York, NY 10027, USA', {'open_now': False}, 2, 4.2), ('Community Food & Juice', '2893 Broadway, New York, NY 10025, USA', {'open_now': False}, 2, 4.1), ('Massawa', '1239 Amsterdam Ave, New York, NY 10027, USA', {'open_now': True}, 2, 4.2), ('Pisticci', '125 La Salle St, New York, NY 10027, USA', {'open_now': True}, 2, 4.6), ('Junzi Kitchen', '2896 Broadway, New York, NY 10025, USA', {'open_now': False}, 1, 4.3), ("Brownie's Cafe", '1172 Amsterdam Ave, New York, NY 10027, USA', {'open_now': False}, None, 4.5), ('Dig Inn', '2884 Broadway, New York, NY 10025, USA', {'open_now': False}, 1, 4.3), ('Max Soha', '1274 Amsterdam Ave, New York, NY 10027, USA', {'open_now': True}, 2, 4.4), ('Thai Market', '960 Amsterdam Ave, New York, NY 10025, USA', {'open_now': False}, 2, 4.3), ("Mel's Burger Bar", '2850 Broadway, New York, NY 10025, USA', {'open_now': True}, 2, 4.1), ('Roti Roll Bombay Frankie', '994 Amsterdam Ave, New York, NY 10025, USA', {'open_now': True}, 1, 4.4), ('Jin Ramen West Harlem', '3183 Broadway, New York, NY 10027, USA', {'open_now': True}, 2, 4.4), ('Kitchenette', '1272 Amsterdam Ave, New York, NY 10027, USA', {'open_now': False}, 2, 4.1), ('Flat Top', '1241 Amsterdam Ave, New York, NY 10027, USA', {'open_now': False}, 2, 4.4), ('V & T', '1024 Amsterdam Ave, New York, NY 10025, USA', {'open_now': True}, 2, 4.2), ('Doaba Deli', '945 Columbus Ave, New York, NY 10025, USA', {'open_now': True}, 1, 4.6), ('Tartina', '1034 Amsterdam Ave, New York, NY 10025, USA', {'open_now': False}, 2, 4.3), ('Saiguette', '935 Columbus Ave, New York, NY 10025, USA', {'open_now': False}, 1, 4.5), ('Chapati House - NYC', '3153 Broadway, New York, NY 10027, USA', {'open_now': True}, 1, 4.4), ('Max Caffè', '1262 Amsterdam Ave, New York, NY 10027, USA', {'open_now': True}, 2, 4.3), ('The Hamilton', '998 Amsterdam Ave, New York, NY 10025, USA', {'open_now': True}, 2, 4.5), ('VINATERÍA', '2211 Frederick Douglass Blvd, New York, NY 10026, USA', {'open_now': False}, 2, 4.5), ('Lido Harlem Restaurant', '2168 Frederick Douglass Blvd, New York, NY 10026, USA', {'open_now': False}, 2, 4.4), ('Shake Shack', '2957 Broadway, New York, NY 10025, USA', {'open_now': True}, 2, 4.2), ('Nikko', '1280 Amsterdam Ave, New York, NY 10027, USA', {'open_now': True}, 2, 4.2), ('Happy Hot Hunan', '969 Amsterdam Ave, New York, NY 10025, USA', {'open_now': False}, 2, 4.2), ('Kosher Cafe Nana', '606 W.115th Street, Second Floor, New York, NY 10025, United States', {'open_now': True}, None, 4.1), ('Crepes On Columbus', '990 Columbus Ave, New York, NY 10025, USA', {'open_now': False}, 2, 4.3), ('The Heights Bar & Grill', '2867 Broadway, New York, NY 10025, USA', {'open_now': True}, 2, 4.1), ('Bettolona', '3143 Broadway, New York, NY 10027, USA', {'open_now': True}, 2, 4.3)]
# 30
# max_results is in incorrect format
# []
# 0
# min_rating is in incorrect format
# []
# 0
